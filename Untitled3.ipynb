# %%
import pandas as pd

# %%
d=pd.read_csv("/content/India_Menu (1).csv")
print(d)
# Out:
#        Menu Category              Menu Items Per Serve Size  Energy (kCal)  \
# 0       Regular Menu        McVeggie™ Burger          168 g         402.05
# 1       Regular Menu    McAloo Tikki Burger®          146 g         339.52
# 2       Regular Menu  McSpicy™ Paneer Burger          199 g         652.76
# 3       Regular Menu       Spicy Paneer Wrap          250 g         674.68
# 4       Regular Menu     American Veg Burger          177 g         512.17
# ..               ...                     ...            ...            ...
# 136  Condiments Menu  Tomato Ketchup Sachets            8 g          11.23
# 137  Condiments Menu             Maple Syrup           30 g          86.40
# 138  Condiments Menu            Cheese Slice           14 g          51.03
# 139  Condiments Menu              Sweet Corn           40 g          45.08
# 140  Condiments Menu    Mixed Fruit Beverage         180 ml          72.25
#
#      Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  \
# 0          10.24          13.83         5.34           0.16
# 1           8.50          11.31         4.27           0.20
# 2          20.29          39.45        17.12           0.18
# 3          20.96          39.10        19.73           0.26
# 4          15.30          23.45        10.51           0.17
# ..           ...            ...          ...            ...
# 136         0.08          23.45         0.00           0.01
# 137         0.00           0.00         0.00           0.00
# 138         3.06           3.99         2.89           0.01
# 139         1.47           1.00         0.22           0.04
# 140         0.65           0.02         0.02           0.02
#
#      Cholesterols (mg)  Total carbohydrate (g)  Total Sugars (g)  \
# 0                 2.49                   56.54              7.90
# 1                 1.47                   50.27              7.05
# 2                21.85                   52.33              8.35
# 3                40.93                   59.27              3.50
# 4                25.24                   56.96              7.85
# ..                 ...                     ...               ...
# 136               0.08                    2.63              2.33
# 137               0.30                   21.60             16.20
# 138              13.43                    0.72              0.54
# 139               2.00                    7.55              2.54
# 140               0.01                   18.00             16.83
#
#      Added Sugars (g)  Sodium (mg)
# 0                4.49       706.13
# 1                4.07       545.34
# 2                5.27      1074.58
# 3                1.08      1087.46
# 4                4.76      1051.24
# ..                ...          ...
# 136              1.64        71.05
# 137              5.34        15.00
# 138              0.00       178.95
# 139              0.00         0.04
# 140              0.00        10.80
#
# [141 rows x 13 columns]

# %%
print(d.isnull)
# Out:
# <bound method DataFrame.isnull of        Menu Category              Menu Items Per Serve Size  Energy (kCal)  \
# 0       Regular Menu        McVeggie™ Burger          168 g         402.05
# 1       Regular Menu    McAloo Tikki Burger®          146 g         339.52
# 2       Regular Menu  McSpicy™ Paneer Burger          199 g         652.76
# 3       Regular Menu       Spicy Paneer Wrap          250 g         674.68
# 4       Regular Menu     American Veg Burger          177 g         512.17
# ..               ...                     ...            ...            ...
# 136  Condiments Menu  Tomato Ketchup Sachets            8 g          11.23
# 137  Condiments Menu             Maple Syrup           30 g          86.40
# 138  Condiments Menu            Cheese Slice           14 g          51.03
# 139  Condiments Menu              Sweet Corn           40 g          45.08
# 140  Condiments Menu    Mixed Fruit Beverage         180 ml          72.25
#
#      Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  \
# 0          10.24          13.83         5.34           0.16
# 1           8.50          11.31         4.27           0.20
# 2          20.29          39.45        17.12           0.18
# 3          20.96          39.10        19.73           0.26
# 4          15.30          23.45        10.51           0.17
# ..           ...            ...          ...            ...
# 136         0.08          23.45         0.00           0.01
# 137         0.00           0.00         0.00           0.00
# 138         3.06           3.99         2.89           0.01
# 139         1.47           1.00         0.22           0.04
# 140         0.65           0.02         0.02           0.02
#
#      Cholesterols (mg)  Total carbohydrate (g)  Total Sugars (g)  \
# 0                 2.49                   56.54              7.90
# 1                 1.47                   50.27              7.05
# 2                21.85                   52.33              8.35
# 3                40.93                   59.27              3.50
# 4                25.24                   56.96              7.85
# ..                 ...                     ...               ...
# 136               0.08                    2.63              2.33
# 137               0.30                   21.60             16.20
# 138              13.43                    0.72              0.54
# 139               2.00                    7.55              2.54
# 140               0.01                   18.00             16.83
#
#      Added Sugars (g)  Sodium (mg)
# 0                4.49       706.13
# 1                4.07       545.34
# 2                5.27      1074.58
# 3                1.08      1087.46
# 4                4.76      1051.24
# ..                ...          ...
# 136              1.64        71.05
# 137              5.34        15.00
# 138              0.00       178.95
# 139              0.00         0.04
# 140              0.00        10.80
#
# [141 rows x 13 columns]>

# %%
d1=d.fillna(0)

# %%
x1=d['Protein (g)']
x2=d['Total fat (g)']
x3=d['Sat Fat (g)']
x4=d['Trans fat (g)']
x5=d['Cholesterols (mg)']
x6=d['Total carbohydrate (g)']
x7=d['Total Sugars (g)']
x8=d['Added Sugars (g)']
x9=d['Sodium (mg)']
y=d['Energy (kCal)']

# %%
import matplotlib.pyplot as plt
plt.plot(x1,y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x1,y)

# %%
import matplotlib.pyplot as plt
plt.plot(x2,y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x2,y)

# %%
import matplotlib.pyplot as plt
plt.plot(x3,y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x3,y)

# %%
import matplotlib.pyplot as plt
plt.plot(x4,y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x4,y)

# %%
import matplotlib.pyplot as plt
plt.plot(x5,y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x5,y)

# %%
import matplotlib.pyplot as plt
plt.plot(x6,y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x6,y)

# %%
import matplotlib.pyplot as plt
plt.plot(x7,y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x7,y)

# %%
import matplotlib.pyplot as plt
plt.plot(x8,y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x8,y)

# %%
import matplotlib.pyplot as plt
plt.plot(x9,y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x9,y)
